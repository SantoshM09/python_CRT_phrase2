# %% [markdown]
# <a href="https://colab.research.google.com/github/SantoshM09/python_CRT_phrase2/blob/main/CRT_Phrase2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Positive or Negative number
a=int(input("enter a number:"))
if a>=0:
      print("postive number")
else:
    print("negative number")
# Out:
# enter a number:-5
# negative number
